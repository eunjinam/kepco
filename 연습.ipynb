# %%
def my_f (a,b,c):
    return (a+b+c)

x=my_f(1,2,3)
x
# Out:
# 6

# %%
def my_f (a,b,c=100):
    return (a+b+c)

my_f(1,2)
# Out:
# 103

# %%
def my_f (a,b,c=100):
    return (a+b+c)

my_f(1,2,4)
# Out:
# 7

# %%
def my_f (a=100,b,c=100):
    return (a+b+c)

my_f(1) #디폴트인자값은 뒤로 보내기
# Out:
#   File "<ipython-input-4-0e44aa88e371>", line 1
#     def my_f (a=100,b,c=100):
#              ^
# SyntaxError: non-default argument follows default argument

# %%
def my_f (b,a=100,c=100):
    return (a+b+c)

my_f(1) #디폴트인자값은 뒤로 보내기
# Out:
# 201

# %%
import numpy as np
np.random.rand(3)
# Out:
# array([0.62725681, 0.73047306, 0.69193376])

# %%
import numpy as np
np.random.rand(3).round(2)
# Out:
# array([0.71, 0.75, 0.38])

# %%
import numpy as np
np.random.randn(3).round(2) #randn 정규분포
# Out:
# array([ 0.6 ,  0.76, -0.09])

# %%
np.random.randint(1,7,10) #1부터 6사이에 10개 숫자를 만들어내라
# Out:
# array([2, 2, 2, 3, 4, 1, 3, 4, 3, 5])

# %%
import matplotlib.pyplot as plt
# %matplotlib inline
y=np.random.rand(10)
plt.plot(range(10),y)

# %%
import matplotlib.pyplot as plt
# %matplotlib inline
x=range(10)
y=np.random.rand(10)
plt.plot(x,y, c='r') #c='r' 컬러는 레드

# %%
import matplotlib.pyplot as plt
# %matplotlib inline
np.random.seed(111) #seed 넘버 고정 (순서는 고정)
x=range(10)
y=np.random.rand(10)
plt.plot(x,y, c='r') #c='r' 컬러는 레드

# %%
import matplotlib.pyplot as plt
# %matplotlib inline
np.random.seed(111) 
x=range(10)
y=np.random.rand(10)
plt.scatter(x,y, c='r') #산포도, x와y의 관계

# %%
import matplotlib.pyplot as plt
# %matplotlib inline
np.random.seed(111) 
x=range(10)
y=np.random.rand(10)
plt.scatter(x,y, c='r',marker='2') #마커모양설정

# %%
import matplotlib.pyplot as plt
# %matplotlib inline
plt.figure(figsize=(4,3))
np.random.seed(111) 
x=range(10)
y=np.random.rand(10)
plt.plot(x,y, c='r',marker='o') #마커모양설정, plot

# %%
import matplotlib.pyplot as plt
# %matplotlib inline
plt.figure(figsize=(4,3))
np.random.seed(111) 
x=range(10)
y=np.random.rand(10)
plt.plot(x,y, c='r',marker='o',linestyle='--') #마커모양설정, plot, 점선표현

# %%
x=np.random.rand(3).round(2)
x
# Out:
# array([0.99, 0.24, 0.08])

# %%
x < 0.5 #array로 리턴해줌(파이썬의 장점)
# Out:
# array([False,  True,  True])

# %%
z = x < 0.5
z
# Out:
# array([False,  True,  True])

# %%
x[z]
# Out:
# array([0.24, 0.08])

# %%
x[x<0.5] #위 3줄을 이 1줄로 바꿀수있음
# Out:
# array([0.24, 0.08])

# %%
(x<0.5).mean() #평균치 구하는 함수 (true(1)의 확률구하기)
# Out:
# 0.6666666666666666

# %%
x=np.random.rand(300)
y=np.random.rand(300)
#plt.scatter(x,y)
(x*x + y*y < 1).mean()*4 #원안에 점을 찍는 조건, 평균치(원안에 들어오는 점의 확률)
# Out:
# 3.1333333333333333

# %%
x=np.random.rand(3000)
y=np.random.rand(3000)
#plt.scatter(x,y)
(x*x + y*y < 1).mean()*4 #원안에 점을 찍는 조건, 평균치(원안에 들어오는 점의 확률)
# Out:
# 3.1493333333333333

# %%
x=np.random.rand(300000)
y=np.random.rand(300000)
#plt.scatter(x,y)
(x*x + y*y < 1).mean()*4 #원안에 점을 찍는 조건, 평균치(원안에 들어오는 점의 확률), 4를 곱하면 파이가 됨
# Out:
# 3.1439333333333335

# %%
x=np.random.rand(3000)
y=np.random.rand(3000)
plt.scatter(x,y,s=1) #size를 1로 (점)
(x*x + y*y < 1).mean()*4
# Out:
# 3.1453333333333333

# %%
import numpy as np
plt.figure(figsize=(3,3))
plt.scatter(x,y,s=1) #size를 1로 (점)
xs = np.linspace(0,1,200) #linspace 0부터 1까지를 200개로 나눔
ys = (1-xs*xs)**(0.5)
plt.plot(xs, ys, c='r')

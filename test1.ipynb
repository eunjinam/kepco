# %%
import pandas as pd
df = pd.read_excel('data/시도별_용도별.xls')
df
# Out:
#     구분       주거용       공공용       서비스업      업무용합계      농림어업       광업  \
# 0   강원   1940933   1400421    6203749    7604170    607139   398287
# 1   개성         0         0          0          0         0        0
# 2   경기  16587710   5533662   33434551   38968213   2371347   317263
# 3   경남   4260988   1427560    8667737   10095297   2141813    95989
# 4   경북   3302463   1578115    8487402   10065517   1747462   224568
# 5   광주   1954876    565527    3174973    3740500     74608     2898
# 6   대구   3151904    826396    5470438    6296834     69142     5858
# 7   대전   1872890    954681    3955921    4910602     28643     3326
# 8   부산   4473510   1305876    7582169    8888045    107927    25289
# 9   서울  13131172   3581534   27647345   31228879     15150     4064
# 10  세종    384903    299675     645424     945099     69469    16364
# 11  울산   1487143    489865    3649386    4139251     80221    20103
# 12  인천   3856852    921748    7154416    8076164    142953    71529
# ...

# %%
import pandas as pd
df = pd.read_excel('data/시도별_용도별.xls')
df
# Out:
#     구분       주거용       공공용       서비스업      업무용합계      농림어업       광업  \
# 0   강원   1940933   1400421    6203749    7604170    607139   398287
# 1   개성         0         0          0          0         0        0
# 2   경기  16587710   5533662   33434551   38968213   2371347   317263
# 3   경남   4260988   1427560    8667737   10095297   2141813    95989
# 4   경북   3302463   1578115    8487402   10065517   1747462   224568
# 5   광주   1954876    565527    3174973    3740500     74608     2898
# 6   대구   3151904    826396    5470438    6296834     69142     5858
# 7   대전   1872890    954681    3955921    4910602     28643     3326
# 8   부산   4473510   1305876    7582169    8888045    107927    25289
# 9   서울  13131172   3581534   27647345   31228879     15150     4064
# 10  세종    384903    299675     645424     945099     69469    16364
# 11  울산   1487143    489865    3649386    4139251     80221    20103
# 12  인천   3856852    921748    7154416    8076164    142953    71529
# ...

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 19 entries, 0 to 18
# Data columns (total 28 columns):
# 구분       19 non-null object
# 주거용      19 non-null int64
# 공공용      19 non-null int64
# 서비스업     19 non-null int64
# 업무용합계    19 non-null int64
# 농림어업     19 non-null int64
# 광업       19 non-null int64
# 제조업      19 non-null int64
# 식료품제조    19 non-null int64
# 섬유,의류    19 non-null int64
# 목재,나무    19 non-null int64
# 펄프,종이    19 non-null int64
# 출판,인쇄    19 non-null int64
# 석유,화확    19 non-null int64
# 의료,광학    19 non-null int64
# 요업       19 non-null int64
# 1차금속     19 non-null int64
# 조립금속     19 non-null int64
# 기타기계     19 non-null int64
# 사무기기     19 non-null int64
# 전기기기     19 non-null int64
# 영상,음향    19 non-null int64
# 자동차      19 non-null int64
# 기타운송     19 non-null int64
# 가구및기타    19 non-null int64
# 재생재료     19 non-null int64
# 산업용합계    19 non-null int64
# 합계       19 non-null int64
# dtypes: int64(27), object(1)
# memory usage: 4.2+ KB

# %%
import maplotlib.pyplot as plt
# %matplotlib inline
df.boxplot()
# Out:
# ---------------------------------------------------------------------------
# ModuleNotFoundError                       Traceback (most recent call last)
# <ipython-input-5-9fe3e3a0c09a> in <module>
# ----> 1 import maplotlib.pyplot as plt
#       2 get_ipython().run_line_magic('matplotlib', 'inline')
#       3 df.boxplot()
#
# ModuleNotFoundError: No module named 'maplotlib'

# %%
import matplotlib.pyplot as plt
# %matplotlib inline
df.boxplot()

# %%
import platform
from matplotlib import font_manager, rc
import matplotlib
matplotlib.rcParams['axes.unicode_minus'] = False

path = "c:\Windows\Fonts\malgun.tff"
font_name = font_manager.FontProperties(fname=path)

# %%
import platform
from matplotlib import font_manager, rc
import matplotlib
matplotlib.rcParams['axes.unicode_minus'] = False

path = "c:\Windows\Fonts\malgun.tff"
font_name = font_manager.FontProperties(fname=path).get_name()
# Out:
# ---------------------------------------------------------------------------
# FileNotFoundError                         Traceback (most recent call last)
# <ipython-input-8-69bb3995f68a> in <module>
#       5
#       6 path = "c:\Windows\Fonts\malgun.tff"
# ----> 7 font_name = font_manager.FontProperties(fname=path).get_name()
#
# C:\Users\eunji\Anaconda3\lib\site-packages\matplotlib\font_manager.py in get_name(self)
#     645         Return the name of the font that best matches the font properties.
#     646         """
# --> 647         return get_font(findfont(self)).family_name
#     648
#     649     def get_style(self):
#
# C:\Users\eunji\Anaconda3\lib\site-packages\matplotlib\font_manager.py in get_font(filename, hinting_factor)
#    1289     if hinting_factor is None:
#    1290         hinting_factor = rcParams['text.hinting_factor']
# -> 1291     return _get_font(filename, hinting_factor)
#    1292
#    1293
#
# ...

# %%
import platform
from matplotlib import font_manager, rc
import matplotlib
matplotlib.rcParams['axes.unicode_minus'] = False
if platform.system()=='Windows':
    path = "c:\Windows\Fonts\malgun.tff"
    font_name = font_manager.FontProperties(fname=path).get_name()
    rc('font',family=font_name)
# Out:
# ---------------------------------------------------------------------------
# FileNotFoundError                         Traceback (most recent call last)
# <ipython-input-9-7dd7baa72558> in <module>
#       5 if platform.system()=='Windows':
#       6     path = "c:\Windows\Fonts\malgun.tff"
# ----> 7     font_name = font_manager.FontProperties(fname=path).get_name()
#       8     rc('font',family=font_name)
#
# C:\Users\eunji\Anaconda3\lib\site-packages\matplotlib\font_manager.py in get_name(self)
#     645         Return the name of the font that best matches the font properties.
#     646         """
# --> 647         return get_font(findfont(self)).family_name
#     648
#     649     def get_style(self):
#
# C:\Users\eunji\Anaconda3\lib\site-packages\matplotlib\font_manager.py in get_font(filename, hinting_factor)
#    1289     if hinting_factor is None:
#    1290         hinting_factor = rcParams['text.hinting_factor']
# -> 1291     return _get_font(filename, hinting_factor)
# ...

# %%
import platform
from matplotlib import font_manager, rc
import matplotlib
matplotlib.rcParams['axes.unicode_minus'] = False
if platform.system()=='Windows':
    path = "c:\Windows\Fonts\malgun Gothic.tff"
    font_name = font_manager.FontProperties(fname=path).get_name()
    rc('font',family=font_name)
# Out:
# ---------------------------------------------------------------------------
# FileNotFoundError                         Traceback (most recent call last)
# <ipython-input-10-7a6daac0429b> in <module>
#       5 if platform.system()=='Windows':
#       6     path = "c:\Windows\Fonts\malgun Gothic.tff"
# ----> 7     font_name = font_manager.FontProperties(fname=path).get_name()
#       8     rc('font',family=font_name)
#
# C:\Users\eunji\Anaconda3\lib\site-packages\matplotlib\font_manager.py in get_name(self)
#     645         Return the name of the font that best matches the font properties.
#     646         """
# --> 647         return get_font(findfont(self)).family_name
#     648
#     649     def get_style(self):
#
# C:\Users\eunji\Anaconda3\lib\site-packages\matplotlib\font_manager.py in get_font(filename, hinting_factor)
#    1289     if hinting_factor is None:
#    1290         hinting_factor = rcParams['text.hinting_factor']
# ...

# %%
import platform
from matplotlib import font_manager, rc
import matplotlib
matplotlib.rcParams['axes.unicode_minus'] = False
if platform.system()=='Windows':
    path = "c:\Windows\Fonts\Malgun Gothic.tff"
    font_name = font_manager.FontProperties(fname=path).get_name()
    rc('font',family=font_name)
# Out:
# ---------------------------------------------------------------------------
# FileNotFoundError                         Traceback (most recent call last)
# <ipython-input-11-47a868f85041> in <module>
#       5 if platform.system()=='Windows':
#       6     path = "c:\Windows\Fonts\Malgun Gothic.tff"
# ----> 7     font_name = font_manager.FontProperties(fname=path).get_name()
#       8     rc('font',family=font_name)
#
# C:\Users\eunji\Anaconda3\lib\site-packages\matplotlib\font_manager.py in get_name(self)
#     645         Return the name of the font that best matches the font properties.
#     646         """
# --> 647         return get_font(findfont(self)).family_name
#     648
#     649     def get_style(self):
#
# C:\Users\eunji\Anaconda3\lib\site-packages\matplotlib\font_manager.py in get_font(filename, hinting_factor)
#    1289     if hinting_factor is None:
#    1290         hinting_factor = rcParams['text.hinting_factor']
# ...

# %%
import platform
from matplotlib import font_manager, rc
import matplotlib
matplotlib.rcParams['axes.unicode_minus'] = False
if platform.system()=='Windows':
    path = "c:\Windows\Fonts\Malgun.ttf"
    font_name = font_manager.FontProperties(fname=path).get_name()
    rc('font',family=font_name)

# %%
import matplotlib.pyplot as plt
# %matplotlib inline
plt.figure(figuresize=(10,8))
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-14-8fe8ff462b4c> in <module>
#       1 import matplotlib.pyplot as plt
#       2 get_ipython().run_line_magic('matplotlib', 'inline')
# ----> 3 plt.figure(figuresize=(10,8))
#
# C:\Users\eunji\Anaconda3\lib\site-packages\matplotlib\pyplot.py in figure(num, figsize, dpi, facecolor, edgecolor, frameon, FigureClass, clear, **kwargs)
#     523                                         frameon=frameon,
#     524                                         FigureClass=FigureClass,
# --> 525                                         **kwargs)
#     526
#     527         if figLabel:
#
# C:\Users\eunji\Anaconda3\lib\site-packages\matplotlib\backend_bases.py in new_figure_manager(cls, num, *args, **kwargs)
#    3215         from matplotlib.figure import Figure
#    3216         fig_cls = kwargs.pop('FigureClass', Figure)
# ...

# %%
import matplotlib.pyplot as plt
# %matplotlib inline
df.boxplot()

# %%
df[['주거용','공공용']].boxplot()

# %%
df.columns
# Out:
# Index(['구분', '주거용', '공공용', '서비스업', '업무용합계', '농림어업', '광업', '제조업', '식료품제조',
#        '섬유,의류', '목재,나무', '펄프,종이', '출판,인쇄', '석유,화확', '의료,광학', '요업', '1차금속',
#        '조립금속', '기타기계', '사무기기', '전기기기', '영상,음향', '자동차', '기타운송', '가구및기타', '재생재료',
#        '산업용합계', '합계'],
#       dtype='object')

# %%
df.head()
# Out:
#    구분       주거용      공공용      서비스업     업무용합계     농림어업      광업       제조업  \
# 0  강원   1940933  1400421   6203749   7604170   607139  398287   6002286
# 1  개성         0        0         0         0        0       0         0
# 2  경기  16587710  5533662  33434551  38968213  2371347  317263  56603327
# 3  경남   4260988  1427560   8667737  10095297  2141813   95989  18053778
# 4  경북   3302463  1578115   8487402  10065517  1747462  224568  30115601
#
#      식료품제조    섬유,의류    ...         기타기계    사무기기     전기기기     영상,음향      자동차  \
# 0   546621    13027    ...        35063    2019    38062     43986   113448
# 1        0        0    ...            0       0        0         0        0
# 2  2544420  2109963    ...      3613798  317244  1040171  24519644  2977165
# 3   932743   346974    ...      1902913    8070   924235    534196  2156059
# 4   566071  3780171    ...       782570   14468   750786   4174971  2356890
#
#       기타운송    가구및기타    재생재료     산업용합계         합계
# ...

# %%
df=df.set_index('구분')
df
# Out:
#          주거용       공공용       서비스업      업무용합계      농림어업       광업        제조업  \
# 구분
# 강원   1940933   1400421    6203749    7604170    607139   398287    6002286
# 개성         0         0          0          0         0        0          0
# 경기  16587710   5533662   33434551   38968213   2371347   317263   56603327
# 경남   4260988   1427560    8667737   10095297   2141813    95989   18053778
# 경북   3302463   1578115    8487402   10065517   1747462   224568   30115601
# 광주   1954876    565527    3174973    3740500     74608     2898    2910768
# 대구   3151904    826396    5470438    6296834     69142     5858    5862633
# 대전   1872890    954681    3955921    4910602     28643     3326    2608343
# 부산   4473510   1305876    7582169    8888045    107927    25289    7512588
# 서울  13131172   3581534   27647345   31228879     15150     4064    1918893
# 세종    384903    299675     645424     945099     69469    16364    1502922
# ...

# %%
df.columns
# Out:
# Index(['주거용', '공공용', '서비스업', '업무용합계', '농림어업', '광업', '제조업', '식료품제조', '섬유,의류',
#        '목재,나무', '펄프,종이', '출판,인쇄', '석유,화확', '의료,광학', '요업', '1차금속', '조립금속',
#        '기타기계', '사무기기', '전기기기', '영상,음향', '자동차', '기타운송', '가구및기타', '재생재료',
#        '산업용합계', '합계'],
#       dtype='object')

# %%
df = df.drop(['산업용합계','업무용합계','합계'], axis = 1)
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# <ipython-input-26-b848d921e211> in <module>
# ----> 1 df = df.drop(['산업용합계','업무용합계','합계'], axis = 1)
#
# C:\Users\eunji\Anaconda3\lib\site-packages\pandas\core\frame.py in drop(self, labels, axis, index, columns, level, inplace, errors)
#    3695                                            index=index, columns=columns,
#    3696                                            level=level, inplace=inplace,
# -> 3697                                            errors=errors)
#    3698
#    3699     @rewrite_axis_style_signature('mapper', [('copy', True),
#
# C:\Users\eunji\Anaconda3\lib\site-packages\pandas\core\generic.py in drop(self, labels, axis, index, columns, level, inplace, errors)
#    3109         for axis, labels in axes.items():
#    3110             if labels is not None:
# ...

# %%
df.drop(['개성'])
df
# Out:
#          주거용       공공용       서비스업      업무용합계      농림어업       광업        제조업  \
# 구분
# 강원   1940933   1400421    6203749    7604170    607139   398287    6002286
# 개성         0         0          0          0         0        0          0
# 경기  16587710   5533662   33434551   38968213   2371347   317263   56603327
# 경남   4260988   1427560    8667737   10095297   2141813    95989   18053778
# 경북   3302463   1578115    8487402   10065517   1747462   224568   30115601
# 광주   1954876    565527    3174973    3740500     74608     2898    2910768
# 대구   3151904    826396    5470438    6296834     69142     5858    5862633
# 대전   1872890    954681    3955921    4910602     28643     3326    2608343
# 부산   4473510   1305876    7582169    8888045    107927    25289    7512588
# 서울  13131172   3581534   27647345   31228879     15150     4064    1918893
# 세종    384903    299675     645424     945099     69469    16364    1502922
# ...

# %%
df
# Out:
#          주거용       공공용       서비스업      농림어업       광업        제조업     식료품제조  \
# 구분
# 강원   1940933   1400421    6203749    607139   398287    6002286    546621
# 개성         0         0          0         0        0          0         0
# 경기  16587710   5533662   33434551   2371347   317263   56603327   2544420
# 경남   4260988   1427560    8667737   2141813    95989   18053778    932743
# 경북   3302463   1578115    8487402   1747462   224568   30115601    566071
# 광주   1954876    565527    3174973     74608     2898    2910768    161072
# 대구   3151904    826396    5470438     69142     5858    5862633    212626
# 대전   1872890    954681    3955921     28643     3326    2608343    204171
# 부산   4473510   1305876    7582169    107927    25289    7512588    532943
# 서울  13131172   3581534   27647345     15150     4064    1918893    227077
# 세종    384903    299675     645424     69469    16364    1502922    110211
# 울산   1487143    489865    3649386     80221    20103   25883132    187738
# ...

# %%
df=df.drop(['개성','합계'], axis = 0, errors='ignore')
df.shape
# Out:
# (17, 24)

# %%
plt.figure(figsize=(10,6))
df.boxplot()
plt.xticks(rotation=90)
plt.show()

# %%
plt.figure(figsize=(10,6))
df[['조립금속','기타기계']].boxplot()
plt.xticks(rotation=90)
plt.show()

# %%
df.plot(kind='barh', figsize=(12,8), stacked=True)
plt.show()

# %%
df.plot(kind='bar', figsize=(12,8), stacked=True) #bar에 h붙이면 horizontal
plt.show()

# %%
df.columns
# Out:
# Index(['주거용', '공공용', '서비스업', '농림어업', '광업', '제조업', '식료품제조', '섬유,의류', '목재,나무',
#        '펄프,종이', '출판,인쇄', '석유,화확', '의료,광학', '요업', '1차금속', '조립금속', '기타기계',
#        '사무기기', '전기기기', '영상,음향', '자동차', '기타운송', '가구및기타', '재생재료'],
#       dtype='object')

# %%
df[['공공용', '서비스업', '농림어업', '광업', '제조업', '식료품제조']].plot(kind='bar', figsize=(12,8), stacked=True)
plt.show()

# %%
df[['공공용', '서비스업', '농림어업', '광업', '제조업', '식료품제조']].plot(kind='bar', figsize=(12,8))
plt.show()

# %%
df[['공공용', '서비스업', '농림어업', '광업', '제조업', '식료품제조']].plot(kind='barh', 
                                                       figsize=(12,8), stacked=True)
plt.show()

# %%
df.boxplot()
df.show()
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# <ipython-input-38-259678a25931> in <module>
#       1 df.boxplot()
# ----> 2 df.show()
#
# C:\Users\eunji\Anaconda3\lib\site-packages\pandas\core\generic.py in __getattr__(self, name)
#    4374             if self._info_axis._can_hold_identifiers_and_holds_name(name):
#    4375                 return self[name]
# -> 4376             return object.__getattribute__(self, name)
#    4377
#    4378     def __setattr__(self, name, value):
#
# AttributeError: 'DataFrame' object has no attribute 'show'

# %%
df.boxplot()
plt.show()
